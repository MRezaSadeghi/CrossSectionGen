# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.transform import Rotation as R

# %%
rotation = R.from_euler('z', 3.14/4, degrees=False)
x = np.array([1, 2, 3, 5])
y = np.array([4, 5, 3, 7])

# %%
R1 = rotation.as_matrix()
A = rotation.apply(np.vstack((x, y, x*0)).T)

# %%
A
# Out:
# array([[-2.11991246e+00,  3.53637826e+00,  0.00000000e+00],
#        [-2.11934937e+00,  4.95059171e+00,  0.00000000e+00],
#        [ 1.68926419e-03,  4.24264035e+00,  0.00000000e+00],
#        [-1.41083492e+00,  8.48584379e+00,  0.00000000e+00]])

# %%
np.vstack((x, y, x*0)).T
# Out:
# array([[1, 4, 0],
#        [2, 5, 0],
#        [3, 3, 0],
#        [5, 7, 0]])

# %%
a = [1, 2]
b = [3, 4]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
v = (a, b, ":k")
ax.plot(*v)
